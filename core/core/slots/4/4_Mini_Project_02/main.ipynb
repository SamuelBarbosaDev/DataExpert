# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
from functools import reduce
import matplotlib.pyplot as plt

# %%
class Walmart():
    """
        Você foi contratado pelo Walmart para fazer um levantamento do
        faturamento das lojas nos USA e apontar qual loja seria melhor para
        expandir seu tamanho.
        
        É preciso analisar as vendas semanais de cada loja, calcular algumas
        informações importantes que serão perguntadas e ao ﬁnal de tudo, indicar
        em qual loja deva ser investida.
    """

    def __init__(self):
        path = r'data/Walmart.csv'
        self.df = pd.read_csv(
            filepath_or_buffer=path,
            date_parser='Date',
            sep=',',
            decimal='.',
        )

    def convertendo_a_coluna_date_para_o_tipo_datetime(self):
        self.df['Date'] = pd.to_datetime(
            arg=self.df['Date'],
            format='%d-%m-%Y'
        )

    def criando_a_coluna_year_e_a_coluna_month(self):
        self.df['month'] = self.df['Date'].dt.month
        self.df['year'] = self.df['Date'].dt.year

    def agrupando_pelo_faturamento_anual_por_loja(self):
        years = [2010, 2011, 2012]
        dfs = {}
        data_frames = []

        for year in years:
            df = self.df[
                (self.df['year'] == year)
            ]

            df.rename(
                columns = {'Weekly_Sales':f'faturamento_{year}'}, 
                inplace = True
            )
            
            dfs[year] = df.groupby('Store').agg({f'faturamento_{year}':'sum'}).astype(int).reset_index()

            data_frames.append(dfs[year])

        self.df_merge = reduce(
            lambda  left, right: 
                pd.merge(
                    left,
                    right,
                    on=['Store'],
                    how='outer'
                ), data_frames
        )

    def agrupando_pelo_faturamento_total(self):
        df = self.df
        df = df.groupby('Store').agg({'Weekly_Sales':'sum'}).astype(int).reset_index()

        faturamento_total = []

        for store in self.df_merge['Store']:
            df_filtrado = df[
                (df['Store'] == store)
            ]['Weekly_Sales'].iloc[0]

            faturamento_total.append(df_filtrado)
            
        self.df_merge['faturamento_total'] = faturamento_total

    def agrupando_pelas_vendas_nos_feriados_anualmente_por_loja(self):
        years = [2010, 2011, 2012]
        dfs = {}
        data_frames = []

        for year in years:
            df = self.df[
                (self.df['year'] == year) &
                (self.df['Holiday_Flag'] == 1)
            ]

            df.rename(
                columns = {'Weekly_Sales':f'venda_nos_feriados_{year}'}, 
                inplace = True
            )
            
            dfs[year] = df.groupby('Store').agg({f'venda_nos_feriados_{year}':'sum'}).astype(int).reset_index()

            data_frames.append(dfs[year])

        df_merge = reduce(
            lambda  left, right: 
                pd.merge(
                    left,
                    right,
                    on=['Store'],
                    how='outer'
                ), data_frames
        )

        self.df_merge = self.df_merge.merge(
            df_merge,
            on='Store'
        )

    def agrupando_pelas_vendas_totais_nos_feriados(self):
        df = self.df

        df = df[
            (df['Holiday_Flag'] == 1)
        ]

        df = df.groupby('Store').agg({'Weekly_Sales':'sum'}).astype(int).reset_index()

        venda_total_nos_feriados = []

        for store in self.df_merge['Store']:
            df_filtrado = df[
                (df['Store'] == store)
            ]['Weekly_Sales'].iloc[0]

            venda_total_nos_feriados.append(df_filtrado)
            
        self.df_merge['venda_total_nos_feriados'] = venda_total_nos_feriados
    
    def agrupando_pelo_preço_médio_semanal_por_loja(self):
        df = self.df[
            [
                'Store',
                'Weekly_Sales'
            ]
        ]

        df = df[(np.abs(stats.zscore(df['Weekly_Sales'])) < 3)]
        df = df.groupby('Store').agg({'Weekly_Sales':'mean'}).astype(int).reset_index()

        média_de_vendas_semanais = []

        for store in self.df_merge['Store']:
            df_filtrado = df[
                (df['Store'] == store)
            ]['Weekly_Sales'].iloc[0]

            média_de_vendas_semanais.append(df_filtrado)

        self.df_merge['média_de_vendas_semanais'] = média_de_vendas_semanais
        
    def criando_a_coluna_ranking_para_rankear_as_lojas(self):
        ranking_das_lojas = []

        for index, store in enumerate(self.df_merge['Store']):
            ranking_das_lojas.append(0)
            
            # -------- Maior_faturamento_total
            faturamento_total = self.df_merge[
                (self.df_merge['Store'] == store)
            ]['faturamento_total'].iloc[0]
            
            maior_faturamento = self.df_merge[
                (self.df_merge['faturamento_total'] == self.df_merge['faturamento_total'].max())
            ]['faturamento_total'].iloc[0]

            # -------- Maior_faturamento_2010
            faturamento_2010 = self.df_merge[
                (self.df_merge['Store'] == store)
            ]['faturamento_2010'].iloc[0]
            
            maior_faturamento_2010 = self.df_merge[
                (self.df_merge['faturamento_2010'] == self.df_merge['faturamento_2010'].max())
            ]['faturamento_2010'].iloc[0]

            # -------- Maior_faturamento_2011
            faturamento_2011 = self.df_merge[
                (self.df_merge['Store'] == store)
            ]['faturamento_2011'].iloc[0]
            
            maior_faturamento_2011 = self.df_merge[
                (self.df_merge['faturamento_2011'] == self.df_merge['faturamento_2011'].max())
            ]['faturamento_2011'].iloc[0]

            # -------- Maior_faturamento_2012
            faturamento_2012 = self.df_merge[
                (self.df_merge['Store'] == store)
            ]['faturamento_2012'].iloc[0]
            
            maior_faturamento_2012 = self.df_merge[
                (self.df_merge['faturamento_2012'] == self.df_merge['faturamento_2012'].max())
            ]['faturamento_2012'].iloc[0]

            # -------- Venda_total_nos_feriados
            venda_total_nos_feriados = self.df_merge[
                (self.df_merge['Store'] == store)
            ]['venda_total_nos_feriados'].iloc[0]
            
            maior_venda_total_nos_feriados = self.df_merge[
                (self.df_merge['venda_total_nos_feriados'] == self.df_merge['venda_total_nos_feriados'].max())
            ]['venda_total_nos_feriados'].iloc[0]

            # -------- Venda_nos_feriados_2010
            venda_nos_feriados_2010 = self.df_merge[
                (self.df_merge['Store'] == store)
            ]['venda_nos_feriados_2010'].iloc[0]
            
            maior_venda_nos_feriados_2010 = self.df_merge[
                (self.df_merge['venda_nos_feriados_2010'] == self.df_merge['venda_nos_feriados_2010'].max())
            ]['venda_nos_feriados_2010'].iloc[0]

            # -------- Venda_nos_feriados_2011
            venda_nos_feriados_2011 = self.df_merge[
                (self.df_merge['Store'] == store)
            ]['venda_nos_feriados_2011'].iloc[0]
            
            maior_venda_nos_feriados_2011 = self.df_merge[
                (self.df_merge['venda_nos_feriados_2011'] == self.df_merge['venda_nos_feriados_2011'].max())
            ]['venda_nos_feriados_2011'].iloc[0]

            # -------- Venda_nos_feriados_2012
            venda_nos_feriados_2012 = self.df_merge[
                (self.df_merge['Store'] == store)
            ]['venda_nos_feriados_2012'].iloc[0]
            
            maior_venda_nos_feriados_2012 = self.df_merge[
                (self.df_merge['venda_nos_feriados_2012'] == self.df_merge['venda_nos_feriados_2012'].max())
            ]['venda_nos_feriados_2012'].iloc[0]

            # -------- Venda_nos_feriados_2012
            média_de_vendas_semanais = self.df_merge[
                (self.df_merge['Store'] == store)
            ]['média_de_vendas_semanais'].iloc[0]
            
            maior_média_de_vendas_semanais = self.df_merge[
                (self.df_merge['média_de_vendas_semanais'] == self.df_merge['média_de_vendas_semanais'].max())
            ]['média_de_vendas_semanais'].iloc[0]

            # -------- Faturamento
            if faturamento_total == maior_faturamento:
                ranking_das_lojas[index] += 30
                print(f'Loja: {store}')

            if faturamento_2010 == maior_faturamento_2010:
                ranking_das_lojas[index] += 10
                print(f'Loja: {store}')

            if faturamento_2011 == maior_faturamento_2011:
                ranking_das_lojas[index] += 10
                print(f'Loja: {store}')

            if faturamento_2012 == maior_faturamento_2012:
                ranking_das_lojas[index] += 10
                print(f'Loja: {store}')

            # -------- Maior taxa de crescimento do faturamento
            if (
                (faturamento_2011 > faturamento_2010) and
                (faturamento_2012 > faturamento_2011)
                ):
                ranking_das_lojas[index] += 50
                print(f'Loja: {store}')

            # -------- Venda nos feriados
            if venda_total_nos_feriados == maior_venda_total_nos_feriados:
                ranking_das_lojas[index] += 30
                print(f'Loja: {store}')

            if venda_nos_feriados_2010 == maior_venda_nos_feriados_2010:
                ranking_das_lojas[index] += 20
                print(f'Loja: {store}')

            if venda_nos_feriados_2011 == maior_venda_nos_feriados_2011:
                ranking_das_lojas[index] += 20
                print(f'Loja: {store}')

            if venda_nos_feriados_2012 == maior_venda_nos_feriados_2012:
                ranking_das_lojas[index] += 20
                print(f'Loja: {store}')

            # -------- Maior taxa de crescimento das vendas nos feriados
            if (
                (venda_nos_feriados_2011 > venda_nos_feriados_2010) and
                (venda_nos_feriados_2012 > venda_nos_feriados_2011)
                ):
                ranking_das_lojas[index] += 50
                print(f'Loja: {store}')

            # -------- Média de vendas semanais
            if média_de_vendas_semanais == maior_média_de_vendas_semanais:
                ranking_das_lojas[index] += 20
                print(f'Loja: {store}')

        self.df_merge['ranking_das_lojas'] = ranking_das_lojas

    def gráfico_faturamento_total_por_loja(self):
        df = self.df_merge.sort_values(
            by='faturamento_total',
            ascending=False,
        ).head(5)

        # ------ Gráfico
        fig, axes = plt.subplots(
                        figsize=(19, 10),
                        dpi=300
                    )
        
        ax = sns.barplot(
            data=df,
            x="Store",
            y="faturamento_total",
            palette=['#d1c8da'],
            label='Total',
        )

        ax = sns.barplot(
            data=df,
            x="Store",
            y="venda_total_nos_feriados",
            palette=["#c06ee2"],
            label= 'Vendas Nos Férias',
        )

        ax.bar_label(
            ax.containers[0],
            fmt='$ %.0f',
            padding=5,
            color='black',
            label_type='center',
        )
        axes.tick_params(
            axis='x', 
            colors='white'
        )
        axes.legend(
            ncol=1, 
            loc="upper left", 
            frameon=True,
            labelcolor='white',
            facecolor='black'
        )
        plt.rcParams['font.size']=15
        axes.spines['top'].set_visible(False)
        axes.spines['right'].set_visible(False)
        axes.spines['bottom'].set_visible(False)
        axes.spines['left'].set_visible(False)
        axes.set_xlabel('')
        axes.set_ylabel('')
        axes.get_yaxis().set_ticks([])

        plt.show()
        fig.savefig(f'img/faturamento_total_por_loja.png', transparent=True)

    def gráfico_venda_total_nos_feriados_por_loja(self):
        df = self.df_merge.sort_values(
            by='faturamento_total',
            ascending=False,
        ).head(5)

        # ------ Gráfico
        fig, axes = plt.subplots(
                        figsize=(19, 10),
                        dpi=300
                    )
        
        bar_colors = ['#d1c8da', '#8870a0', '#ff9e43', '#c06ee2', '#ff4093']

        ax = sns.barplot(
            data=df,
            x="Store",
            y="venda_total_nos_feriados",
            palette=bar_colors,
            label='Total',
        )

        ax.bar_label(
            ax.containers[0],
            fmt='$ %.0f',
            padding=5,
            color='snow',
            label_type='edge',
        )
        axes.tick_params(
            axis='x', 
            colors='white'
        )

        plt.rcParams['font.size']=15
        axes.spines['top'].set_visible(False)
        axes.spines['right'].set_visible(False)
        axes.spines['bottom'].set_visible(False)
        axes.spines['left'].set_visible(False)
        axes.set_xlabel('')
        axes.set_ylabel('')
        axes.get_yaxis().set_ticks([])

        plt.show()
        fig.savefig(f'img/venda_total_nos_feriados_por_loja.png', transparent=True)

    def gráfico_média_de_vendas_semanais_por_loja(self):
        df = self.df_merge.sort_values(
            by='faturamento_total',
            ascending=False,
        ).head(5)

        # ------ Gráfico
        fig, axes = plt.subplots(
                        figsize=(19, 10),
                        dpi=300
                    )
        
        bar_colors = ['#d1c8da', '#8870a0', '#ff9e43', '#c06ee2', '#ff4093']

        ax = sns.barplot(
            data=df,
            x="Store",
            y="média_de_vendas_semanais",
            palette=bar_colors,
            label='Total',
        )

        ax.bar_label(
            ax.containers[0],
            fmt='$ %.0f',
            padding=5,
            color='snow',
            label_type='edge',
        )
        axes.tick_params(
            axis='x', 
            colors='white'
        )

        plt.rcParams['font.size']=15
        axes.spines['top'].set_visible(False)
        axes.spines['right'].set_visible(False)
        axes.spines['bottom'].set_visible(False)
        axes.spines['left'].set_visible(False)
        axes.set_xlabel('')
        axes.set_ylabel('')
        axes.get_yaxis().set_ticks([])

        plt.show()
        fig.savefig(f'img/média_de_vendas_semanais_por_loja.png', transparent=True)

    def gráfico_faturamento_mês_a_mês_da_melhor_loja(self):
        store = self.df_merge.sort_values(
                by='ranking_das_lojas',
                ascending=False
        )['Store'].iloc[0]

        years = [2010, 2011, 2012]


        # ------ Filtrando pela melhor loja é Agrupando por data: 
        df = self.df[
            (self.df['Store'] == store)
        ]

        df = df.groupby(['Store', 'month', 'year']).agg({'Weekly_Sales':'sum'}).astype(int).reset_index()

        # ------ Filtrando pelas vendas nos feriados:
        df_feriados = self.df[
            (self.df['Store'] == store) &
            (self.df['Holiday_Flag'] == 1)
        ]

        df_feriados = df_feriados.groupby(['Store', 'month', 'year']).agg({'Weekly_Sales':'sum'}).astype(int).reset_index()
        
        # ------ Criando a coluna venda_nos_feriados:
        venda_nos_feriados = []
        
        for year, month in zip(df['year'], df['month']):
            try:
                df_filtrado = df_feriados[
                    (df_feriados['year'] == year) &
                    (df_feriados['month'] == month)
                ]['Weekly_Sales'].iloc[0]

                venda_nos_feriados.append(df_filtrado)


            except IndexError:
                venda_nos_feriados.append(0)
        
        df['venda_nos_feriados'] = venda_nos_feriados


        # ------ Criando os gráficos de barras:
        for year in years:

            df_grafico = df[
                (df['year'] == year)
            ]

            fig, axes = plt.subplots(
                figsize=(19, 10),
                dpi=300
            )

            ax1 = axes.bar(
                data=df_grafico,
                x="month",
                height='Weekly_Sales',
                color="#ff9e43",
                label='Total',
                bottom=0,
                width=0.8,
            )

            ax2 = axes.bar(
                data=df_grafico,
                x="month",
                height='venda_nos_feriados',
                color="#c06ee2",
                label= 'Vendas Nos Férias',
                bottom=0,
                width=0.8,
            )

            axes.legend(
                ncol=1, 
                loc="upper left", 
                frameon=True,
                labelcolor='white',
                facecolor='black'
            )

            axes.bar_label(
                ax1,
                fmt='$%.0f',
                padding=2,
                label_type='edge',
                color='snow',
            )

            axes.tick_params(
                axis='x', 
                colors='white'
            )

            plt.rcParams['font.size']=15


            axes.spines['top'].set_visible(False)
            axes.spines['right'].set_visible(False)
            axes.spines['bottom'].set_visible(False)
            axes.spines['left'].set_visible(False)

            axes.get_yaxis().set_ticks([])
            axes.get_xaxis().set_ticks(df_grafico['month'])

            plt.show()
            fig.savefig(f'img/{year}.png', transparent=True)

    def gráfico_faturamento_ano_a_ano_da_melhor_loja(self):
        store = self.df_merge.sort_values(
                by='ranking_das_lojas',
                ascending=False
        )['Store'].iloc[0]


        # ------ Filtrando pela melhor loja é Agrupando por data: 
        df = self.df[
            (self.df['Store'] == store)
        ]

        df = df.groupby(['Store', 'year']).agg({'Weekly_Sales':'sum'}).astype(int).reset_index()

        # ------ Gráfico
        fig, axes = plt.subplots(
                        figsize=(19, 10),
                        dpi=300
                    )
        
        bar_colors = ['#ff9e43', '#c06ee2', '#ff4093']

        ax1 = axes.bar(
            data=df,
            x="year",
            height='Weekly_Sales',
            color=bar_colors,
            label='Total',
            bottom=0,
            width=0.8,
        )
        
        axes.bar_label(
            ax1,
            fmt='$%.0f',
            padding=2,
            label_type='edge',
            color='snow',
        )
        axes.tick_params(
            axis='x', 
            colors='white'
        )
        plt.rcParams['font.size']=15
        axes.spines['top'].set_visible(False)
        axes.spines['right'].set_visible(False)
        axes.spines['bottom'].set_visible(False)
        axes.spines['left'].set_visible(False)
        axes.get_yaxis().set_ticks([])
        axes.get_xaxis().set_ticks(df['year'])
        plt.show()
        fig.savefig(f'img/gráfico_ano_a_ano.png', transparent=True)

    def dataframe(self):
        df = self.df_merge[
                [
                    'Store',
                    'ranking_das_lojas',
                    'faturamento_2010',
                    'faturamento_2011',
                    'faturamento_2012',
                    'faturamento_total',
                    'venda_nos_feriados_2010',
                    'venda_nos_feriados_2011',
                    'venda_nos_feriados_2012',
                    'venda_total_nos_feriados',
                    'média_de_vendas_semanais'
                ]
        ].sort_values(
            by='ranking_das_lojas',
            ascending=False
        ).reset_index(drop=True)
        
        display(
            df
        )

if __name__ == '__main__':
    walmart = Walmart()

# %%
walmart.convertendo_a_coluna_date_para_o_tipo_datetime()

# %%
walmart.criando_a_coluna_year_e_a_coluna_month()

# %%
walmart.agrupando_pelo_faturamento_anual_por_loja()
# Out:
# /tmp/ipykernel_33249/1344996698.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(
# /tmp/ipykernel_33249/1344996698.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(
# /tmp/ipykernel_33249/1344996698.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(

# %%
walmart.agrupando_pelo_faturamento_total()

# %%
walmart.agrupando_pelas_vendas_nos_feriados_anualmente_por_loja()
# Out:
# /tmp/ipykernel_33249/1344996698.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(
# /tmp/ipykernel_33249/1344996698.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(
# /tmp/ipykernel_33249/1344996698.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(

# %%
walmart.agrupando_pelas_vendas_totais_nos_feriados()

# %%
walmart.agrupando_pelo_preço_médio_semanal_por_loja()

# %%
walmart.criando_a_coluna_ranking_para_rankear_as_lojas()
# Out:
# Loja: 4
# Loja: 4
# Loja: 4
# Loja: 14
# Loja: 20
# Loja: 20
# Loja: 20
# Loja: 20
# Loja: 20

# %%
walmart.gráfico_faturamento_total_por_loja()

# %%
walmart.gráfico_venda_total_nos_feriados_por_loja()

# %%
walmart.gráfico_média_de_vendas_semanais_por_loja()

# %%
walmart.gráfico_faturamento_mês_a_mês_da_melhor_loja()

# %%
walmart.gráfico_faturamento_ano_a_ano_da_melhor_loja()

# %%
walmart.dataframe()
# Out:
#     Store  ranking_das_lojas  faturamento_2010  faturamento_2011  \
# 0      20                120         101733080         109837002
# 1       4                 40          95680470         111092293
# 2      14                 10         105462242         106096270
# 3       1                  0          73278832          80921918
# 4      27                  0          90013176          91922684
# 5      28                  0          64778764          69156008
# 6      29                  0          26946827          27950345
# 7      30                  0          21739086          22182148
# 8      31                  0          65560272          74169225
# 9      32                  0          55190936          61347193
# 10     33                  0          12766834          12957836
# 11     34                  0          46150416          50360182
# 12     35                  0          52195970          44086978
# 13     25                  0          35136267          36434405
# 14     36                  0          21153125          18972618
# 15     37                  0          24508469          27081495
# 16     38                  0          16587794          19940758
# 17     39                  0          65782276          75777603
# 18     40                  0          46357359          50340542
# 19     41                  0          57738220          66715874
# 20     42                  0          25498089          29117302
# 21     43                  0          31537005          32053195
# 22     44                  0          13607519          15498194
# 23     26                  0          48390697          52049251
# 24     23                  0          67709105          72273533
# 25     24                  0          66890648          69938976
# 26      2                  0          95277864          98607881
# 27      3                  0          18745419          20816876
# 28      5                  0          14836030          16470820
# 29      6                  0          76912320          80528762
# 30      7                  0          25568078          30662640
# 31      8                  0          43204474          47512786
# 32      9                  0          25129219          28685969
# 33     10                  0          94472202          98916894
# 34     11                  0          65255138          70523582
# 35     12                  0          48370383          52582000
# 36     13                  0          95272735         104537513
# 37     15                  0          32023528          32282624
# 38     16                  0          24728632          27421367
# 39     17                  0          41104920          46391839
# 40     18                  0          55978417          54217740
# 41     19                  0          72580528          74841900
# 42     21                  0          37631108          40234883
# 43     22                  0          50865280          53554711
# 44     45                  0          38536343          41135367
#
#     faturamento_2012  faturamento_total  venda_nos_feriados_2010  \
# 0           89827709          301397792                  8735434
# 1           92771189          299543953                  8638466
# 2           77441398          288999911                  8441412
# 3           68202058          222402808                  6472362
# 4           71920056          253855916                  7727731
# 5           55328907          189263680                  5832622
# 6           22244381           77141554                  2462224
# 7           18795650           62716885                  1812900
# 8           59884407          199613905                  5909053
# 9           50281116          166819246                  4742301
# 10          11435551           37160221                  1027567
# 11          41739164          138249763                  4138438
# 12          35237722          131520672                  4488700
# 13          29490505          101061179                  2977509
# 14          13286470           53412214                  1672237
# 15          22612774           74202740                  2018701
# 16          18631073           55159626                  1343209
# 17          65885662          207445542                  5925262
# 18          41172407          137870309                  3900110
# 19          56887839          181341934                  5116800
# 20          24950359           79565752                  2116051
# 21          26975233           90565435                  2573299
# 22          14187373           43293087                  1119895
# 23          42976444          143416393                  4222012
# 24          58767978          198750617                  5896193
# 25          57186396          194016021                  5876482
# 26          81496695          275382440                  8386098
# 27          18024439           57586735                  1721235
# 28          14168838           45475688                  1404901
# 29          66315047          223756130                  6762011
# 30          25367556           81598275                  2624635
# 31          39233920          129951181                  3861506
# 32          23974029           77789218                  2265354
# 33          78228616          271617713                  8543803
# 34          58184065          193962786                  5735358
# 35          43334845          144287230                  4514096
# 36          86707455          286517703                  8244769
# 37          24827530           89133683                  2988185
# 38          22102425           74252425                  2236718
# 39          40285378          127782138                  3684151
# 40          44918576          155114734                  4740748
# 41          59212433          206634862                  6396518
# 42          30251886          108117878                  3401909
# 43          42655656          147075648                  4285510
# 44          32723630          112395341                  3240105
#
#     venda_nos_feriados_2011  venda_nos_feriados_2012  \
# 0                   9211408                  4543507
# 1                   9292794                  4499765
# 2                   8782648                  3981768
# 3                   6720869                  3464244
# 4                   7702700                  3492560
# 5                   5907163                  3042660
# 6                   2520702                  1086651
# 7                   1670760                   884931
# 8                   6205406                  2885800
# 9                   5039430                  2256108
# 10                  1029396                   568981
# 11                  4257268                  2024073
# 12                  4420171                  1834612
# 13                  3088792                  1330467
# 14                  1374698                   629470
# 15                  2002669                  1053879
# 16                  1511827                   960062
# 17                  6533211                  3052800
# 18                  4092196                  2088033
# 19                  5601689                  2630988
# 20                  2268565                  1292324
# 21                  2460150                  1326012
# 22                  1176344                   664115
# 23                  4335576                  2162879
# 24                  5943622                  2785606
# 25                  5993904                  2880595
# 26                  8404471                  4002099
# 27                  1775352                   881522
# 28                  1490225                   699888
# 29                  6818386                  3228680
# 30                  2938029                  1161337
# 31                  3938241                  1953560
# 32                  2448605                  1175548
# 33                  8666877                  3926879
# 34                  5869714                  2878872
# 35                  4712830                  2154476
# 36                  8650587                  4235080
# 37                  2860396                  1215478
# 38                  2419712                  1010905
# 39                  3978019                  2135798
# 40                  4708336                  2245136
# 41                  6377378                  2996570
# 42                  3449523                  1413480
# 43                  4532159                  2031076
# 44                  3552662                  1570169
#
#     venda_total_nos_feriados  média_de_vendas_semanais
# 0                   22490350                   2058998
# 1                   22431026                   2051352
# 2                   21205829                   1986529
# 3                   16657476                   1555264
# 4                   18922992                   1766040
# 5                   14782446                   1323522
# 6                    6069578                    539451
# 7                    4368593                    438579
# 8                   15000260                   1395901
# 9                   12037840                   1166568
# 10                   2625945                    259861
# 11                  10419780                    966781
# 12                  10743484                    919724
# 13                   7396768                    706721
# 14                   3676406                    373511
# 15                   5075250                    518900
# 16                   3815098                    385731
# 17                  15511274                   1450668
# 18                  10080340                    964128
# 19                  13349478                   1268125
# 20                   5676941                    556403
# 21                   6359462                    633324
# 22                   2960356                    302748
# 23                  10720468                   1002911
# 24                  14625422                   1389864
# 25                  14750982                   1356755
# 26                  20792669                   1905830
# 27                   4378110                    402704
# 28                   3595016                    318011
# 29                  16809079                   1564728
# 30                   6724002                    570617
# 31                   9753308                    908749
# 32                   5889508                    543980
# 33                  21137559                   1852745
# 34                  14483944                   1356383
# 35                  11381404                   1009001
# 36                  21130438                   1957682
# 37                   7064060                    623312
# 38                   5667336                    519247
# 39                   9797969                    893581
# 40                  11694221                   1084718
# 41                  15770467                   1444999
# 42                   8264913                    756069
# 43                  10848746                   1028501
# 44                   8362937                    785981
